# %% [markdown]
# # Crawler para encontrar e baixar vídeos do youtube baseado em um assunto

# %% [markdown]
# ## Import das bibliotecas

# %%
# !pip install pandas
# !pip install youtube_dl
# Out:
# Requirement already satisfied: pandas in c:\users\csorgo\pycharmprojects\miau\venv\lib\site-packages (1.2.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\csorgo\pycharmprojects\miau\venv\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\csorgo\pycharmprojects\miau\venv\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\csorgo\pycharmprojects\miau\venv\lib\site-packages (from pandas) (1.20.3)
# Requirement already satisfied: six>=1.5 in c:\users\csorgo\pycharmprojects\miau\venv\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: youtube_dl in c:\users\csorgo\pycharmprojects\miau\venv\lib\site-packages (2021.6.6)

# %%
import time
import subprocess
import pandas as pd
from youtube_dl import YoutubeDL
from __future__ import unicode_literals

# %% [markdown]
# ## Configurações iniciais

# %%
# Dataset do google com labels adicionados manualmente referente a eventos de audio. Leia mais em: https://research.google.com/audioset/index.html
# Também pode ser obtido em: http://storage.googleapis.com/us_audioset/youtube_corpus/v1/csv/eval_segments.csv
df_eval_segments = pd.read_csv('../../data/external/eval_segments.csv', skipinitialspace = True, quotechar='"', names=["YTID", "start_seconds", "end_seconds", "labels"])

# Dataset contendo os nomes e demais informações dos eventos.
# Também pode ser obtido em: http://storage.googleapis.com/us_audioset/youtube_corpus/v1/csv/class_labels_indices.csv
df_class_labels_index = pd.read_csv('../../data/external/youtube_class_labels_index.csv')

# %%
# Remoção das 3 primeiras linhas. Contém informações sobre o dataset e não serviriam para a automação
df_eval_segments = df_eval_segments.iloc[3:]

# %%
# Filtrando o dataset pelas linhas que contem o label referente a categoria Cat
df_eval_segments = df_eval_segments[df_eval_segments.labels.str.contains('/m/01yrx')]

# %%
# Métodos para substituir os labels de df_eval_segments pelo display_name do dataframe `df_class_labels_index` para facil compreensão

#captura o nome do label no dataset df_class_labels_index
def label_description(label):
  return df_class_labels_index[df_class_labels_index.mid == label]['display_name'].values[0]

#substitui o código do label pelo nome do labeldef get_text_from_label(labels):
def get_text_from_label(labels):
  labels_array = labels.split(',')

  for label in labels_array:
    labels = labels.replace(label, label_description(label))
    
  return labels

# %%
#cria nova coluna com o nome dos labels
df_eval_segments['Label_names'] = df_eval_segments['labels'].apply(lambda x: get_text_from_label(x) )

# %%
# Calcula a duração do intervalo desejado em segundos

# Converte as colunas de str para float
df_eval_segments = df_eval_segments.astype({"end_seconds": float, "start_seconds": float})

# Insere em nova coluna
df_eval_segments.insert(loc=3, column='duration_seconds', value=df_eval_segments['end_seconds'] - df_eval_segments['start_seconds'])

# %% [markdown]
# ## Funções para download e conversão dos audios

# %%
def download_youtube_audio(yt_id, start, duration):
  destination_folder = '../../data/raw/youtube_audios/' + yt_id + '.wav'
  
  ydl_opts = {
      'format': 'bestaudio/best',
      'postprocessors': [{
          'key': 'FFmpegExtractAudio',
          'preferredcodec': 'wav',
          'preferredquality': '192',
      }],
      'outtmpl': destination_folder
  }

  yt_url = 'https://www.youtube.com/watch?v=' + yt_id

  retorno = ''

  try:
    ydl = YoutubeDL(ydl_opts)
    result = ydl.extract_info(yt_url, download=True)
    video = result['entries'][0] if 'entries' in result else result

    url = video['url']
    retorno = video['title']

    # Atrasando o download do prõximo video para não bloquear o google
    time.sleep(1)
  except Exception as e:
      retorno = e

  return retorno

# %%
def download_audio_dataset(df):
  line = 0
  df['title'] = ''

  for index, row in df.iterrows():
    yt_id = row[0]
    start = row[1]
    duration = row[3]
    
    line = line + 1
    df.loc[index, 'title'] = download_youtube_audio(yt_id, start, duration)

  return df

# %%
df_with_titles = download_audio_dataset(df_eval_segments)
# Out:
# ing webpage
# [download] Destination: ..\..\data\raw\youtube_audios\8ewn7JCJbEM.wav
# [download] 100% of 1.05MiB in 00:00
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\8ewn7JCJbEM.wav exists, skipping
# [youtube] 8gyY5kN5IjA: Downloading webpage
# [download] Destination: ..\..\data\raw\youtube_audios\8gyY5kN5IjA.wav
# [download] 100% of 865.55KiB in 00:00
# [ffmpeg] Correcting container in "..\..\data\raw\youtube_audios\8gyY5kN5IjA.wav"
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\8gyY5kN5IjA.wav exists, skipping
# [youtube] 8ws1ligErwo: Downloading webpage
# [youtube] 8ws1ligErwo: Downloading MPD manifest
# [download] Destination: ..\..\data\raw\youtube_audios\8ws1ligErwo.wav
# [download] 100% of 156.66KiB in 00:00
# [ffmpeg] Correcting container in "..\..\data\raw\youtube_audios\8ws1ligErwo.wav"
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\8ws1ligErwo.wav exists, skipping
# [youtube] 8xoenlVVBZw: Downloading webpage
# [download] Destination: ..\..\data\raw\youtube_audios\8xoenlVVBZw.wav
# [download] 100% of 1.44MiB in 00:00
# [ffmpeg] Correcting container in "..\..\data\raw\youtube_audios\8xoenlVVBZw.wav"
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\8xoenlVVBZw.wav exists, skipping
# [youtube] AmDDp-cCo24: Downloading webpage
# [download] Destination: ..\..\data\raw\youtube_audios\AmDDp-cCo24.wav
# [download] 100% of 391.65KiB in 00:00
# [ffmpeg] Correcting container in "..\..\data\raw\youtube_audios\AmDDp-cCo24.wav"
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\AmDDp-cCo24.wav exists, skipping
# [youtube] Ar5r0pzgaRU: Downloading webpage
# [download] Destination: ..\..\data\raw\youtube_audios\Ar5r0pzgaRU.wav
# [download] 100% of 655.37KiB in 00:00
# [ffmpeg] Correcting container in "..\..\data\raw\youtube_audios\Ar5r0pzgaRU.wav"
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\Ar5r0pzgaRU.wav exists, skipping
# [youtube] BLlnu2Tyqu0: Downloading webpage
# [download] Destination: ..\..\data\raw\youtube_audios\BLlnu2Tyqu0.wav
# [download] 100% of 1.17MiB in 00:00
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\BLlnu2Tyqu0.wav exists, skipping
# [youtube] CQGQV-JxPoI: Downloading webpage
# [youtube] CQGQV-JxPoI: Downloading MPD manifest
# [download] Destination: ..\..\data\raw\youtube_audios\CQGQV-JxPoI.wav
# [download] 100% of 1.25MiB in 00:00
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\CQGQV-JxPoI.wav exists, skipping
# [youtube] DjcbzPb1_Tk: Downloading webpage
# [youtube] DjcbzPb1_Tk: Downloading MPD manifest
# [download] Destination: ..\..\data\raw\youtube_audios\DjcbzPb1_Tk.wav
# [download] 100% of 1.81MiB in 00:00
# [ffmpeg] Correcting container in "..\..\data\raw\youtube_audios\DjcbzPb1_Tk.wav"
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\DjcbzPb1_Tk.wav exists, skipping
# [youtube] Fup02r6oh-8: Downloading webpage
# [youtube] Fup02r6oh-8: Downloading MPD manifest
# [download] Destination: ..\..\data\raw\youtube_audios\Fup02r6oh-8.wav
# [download] 100% of 1.72MiB in 00:00
# [ffmpeg] Correcting container in "..\..\data\raw\youtube_audios\Fup02r6oh-8.wav"
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\Fup02r6oh-8.wav exists, skipping
# [youtube] HSPBrLMYWQA: Downloading webpage
# [download] Destination: ..\..\data\raw\youtube_audios\HSPBrLMYWQA.wav
# [download] 100% of 878.60KiB in 00:00
# [ffmpeg] Correcting container in "..\..\data\raw\youtube_audios\HSPBrLMYWQA.wav"
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\HSPBrLMYWQA.wav exists, skipping
# [youtube] Hjyl1n_1muU: Downloading webpage
# [youtube] Hjyl1n_1muU: Downloading MPD manifest
# [download] Destination: ..\..\data\raw\youtube_audios\Hjyl1n_1muU.wav
# [download] 100% of 184.11KiB in 00:00
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\Hjyl1n_1muU.wav exists, skipping
# [youtube] HrvdzCGjbzw: Downloading webpage
# [download] Destination: ..\..\data\raw\youtube_audios\HrvdzCGjbzw.wav
# [download] 100% of 1.86MiB in 00:00
# [ffmpeg] Correcting container in "..\..\data\raw\youtube_audios\HrvdzCGjbzw.wav"
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\HrvdzCGjbzw.wav exists, skipping
# [youtube] I1GC1yWdM_c: Downloading webpage
# [download] Destination: ..\..\data\raw\youtube_audios\I1GC1yWdM_c.wav
# [download] 100% of 1.85MiB in 00:00
# [ffmpeg] Correcting container in "..\..\data\raw\youtube_audios\I1GC1yWdM_c.wav"
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\I1GC1yWdM_c.wav exists, skipping
# [youtube] IcDsqSC5Z-c: Downloading webpage
# [download] Destination: ..\..\data\raw\youtube_audios\IcDsqSC5Z-c.wav
# [download] 100% of 2.78MiB in 00:00
# [ffmpeg] Correcting container in "..\..\data\raw\youtube_audios\IcDsqSC5Z-c.wav"
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\IcDsqSC5Z-c.wav exists, skipping
# [youtube] LHY9L1MjQvQ: Downloading webpage
# [youtube] LHY9L1MjQvQ: Downloading MPD manifest
# [download] Destination: ..\..\data\raw\youtube_audios\LHY9L1MjQvQ.wav
# [download] 100% of 4.65MiB in 00:00
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\LHY9L1MjQvQ.wav exists, skipping
# [youtube] LPvJFjsxMj8: Downloading webpage
# [download] Destination: ..\..\data\raw\youtube_audios\LPvJFjsxMj8.wav
# [download] 100% of 3.07MiB in 00:00
# [ffmpeg] Correcting container in "..\..\data\raw\youtube_audios\LPvJFjsxMj8.wav"
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\LPvJFjsxMj8.wav exists, skipping
# [youtube] LdOQ6qtoQ4I: Downloading webpage
# [download] Destination: ..\..\data\raw\youtube_audios\LdOQ6qtoQ4I.wav
# [download] 100% of 2.70MiB in 00:00
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\LdOQ6qtoQ4I.wav exists, skipping
# [youtube] LyIhmCTPLUc: Downloading webpage
# ERROR: unable to download video data: HTTP Error 403: Forbidden
# [youtube] MF88IYF2MHY: Downloading webpage
# [download] Destination: ..\..\data\raw\youtube_audios\MF88IYF2MHY.wav
# [download] 100% of 918.27KiB in 00:00
# [ffmpeg] Correcting container in "..\..\data\raw\youtube_audios\MF88IYF2MHY.wav"
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\MF88IYF2MHY.wav exists, skipping
# [youtube] NjazulpHxNY: Downloading webpage
# ERROR: unable to download video data: HTTP Error 403: Forbidden
# [youtube] OEmncpMnPak: Downloading webpage
# [youtube] OEmncpMnPak: Downloading MPD manifest
# [download] Destination: ..\..\data\raw\youtube_audios\OEmncpMnPak.wav
# [download] 100% of 625.19KiB in 00:00
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\OEmncpMnPak.wav exists, skipping
# [youtube] OV8eysG8KEk: Downloading webpage
# [download] Destination: ..\..\data\raw\youtube_audios\OV8eysG8KEk.wav
# [download] 100% of 131.99KiB in 00:00
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\OV8eysG8KEk.wav exists, skipping
# [youtube] Pyt8O3N6-wk: Downloading webpage
# ERROR: Private video
# Sign in if you've been granted access to this video
# [youtube] QBjKntYuUIk: Downloading webpage
# [download] Destination: ..\..\data\raw\youtube_audios\QBjKntYuUIk.wav
# [download] 100% of 626.80KiB in 00:10
# [ffmpeg] Correcting container in "..\..\data\raw\youtube_audios\QBjKntYuUIk.wav"
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\QBjKntYuUIk.wav exists, skipping
# [youtube] QiFBbt-6yfU: Downloading webpage
# [youtube] QiFBbt-6yfU: Downloading MPD manifest
# [download] Destination: ..\..\data\raw\youtube_audios\QiFBbt-6yfU.wav
# [download] 100% of 422.36KiB in 00:00
# [ffmpeg] Correcting container in "..\..\data\raw\youtube_audios\QiFBbt-6yfU.wav"
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\QiFBbt-6yfU.wav exists, skipping
# [youtube] R3_Gqgl-NYE: Downloading webpage
# [download] Destination: ..\..\data\raw\youtube_audios\R3_Gqgl-NYE.wav
# [download] 100% of 1.02MiB in 00:00
# [ffmpeg] Correcting container in "..\..\data\raw\youtube_audios\R3_Gqgl-NYE.wav"
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\R3_Gqgl-NYE.wav exists, skipping
# [youtube] RF8fPkV9HNc: Downloading webpage
# [download] Destination: ..\..\data\raw\youtube_audios\RF8fPkV9HNc.wav
# [download] 100% of 358.00KiB in 00:00
# [ffmpeg] Correcting container in "..\..\data\raw\youtube_audios\RF8fPkV9HNc.wav"
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\RF8fPkV9HNc.wav exists, skipping
# [youtube] Rr84-EZvO0U: Downloading webpage
# [download] Destination: ..\..\data\raw\youtube_audios\Rr84-EZvO0U.wav
# [download] 100% of 1.83MiB in 00:00
# [ffmpeg] Correcting container in "..\..\data\raw\youtube_audios\Rr84-EZvO0U.wav"
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\Rr84-EZvO0U.wav exists, skipping
# [youtube] UfMr4FFsS28: Downloading webpage
# [download] Destination: ..\..\data\raw\youtube_audios\UfMr4FFsS28.wav
# [download] 100% of 489.25KiB in 00:00
# [ffmpeg] Correcting container in "..\..\data\raw\youtube_audios\UfMr4FFsS28.wav"
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\UfMr4FFsS28.wav exists, skipping
# [youtube] UoelVWyciuE: Downloading webpage
# [download] Destination: ..\..\data\raw\youtube_audios
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\zE6BVRSQNZU.wav exists, skipping
# [youtube] zh4tznWde1M: Downloading webpage
# [download] Destination: ..\..\data\raw\youtube_audios\zh4tznWde1M.wav
# [download] 100% of 31.48MiB in 00:01
# [ffmpeg] Post-process file ..\..\data\raw\youtube_audios\zh4tznWde1M.wav exists, skipping
# [youtube] zxd98l89Prk: Downloading webpage
# ERROR: Video unavailable

# %% [markdown]
# ## Resumo dos downloads

# %%
df_with_titles
# Out:
#               YTID  start_seconds  end_seconds  duration_seconds  \
# 79     -9byM5-ih2M            0.0         10.0              10.0
# 224    -ZJqu_4zLMc           30.0         40.0              10.0
# 269    -gSfPQqi6nI           30.0         40.0              10.0
# 366    -uGHAvfqs2I           30.0         40.0              10.0
# 370    -vZ-_4oFCzs           17.0         27.0              10.0
# ...            ...            ...          ...               ...
# 19701  xa-lg7S1vns           51.0         61.0              10.0
# 20151  zCdOEvduBTo           30.0         40.0              10.0
# 20164  zE6BVRSQNZU           50.0         60.0              10.0
# 20298  zh4tznWde1M          330.0        340.0              10.0
# 20365  zxd98l89Prk           36.0         46.0              10.0
#
#                                                   labels  \
# 79     /m/01yrx,/m/068hy,/m/07qrkrw,/m/07r_k2n,/m/07r...
# 224    /m/01yrx,/m/068hy,/m/07qrkrw,/m/07r81j2,/m/09x...
# 269      /m/01yrx,/m/068hy,/m/07qrkrw,/m/07r81j2,/m/0jbk
# 366      /m/01yrx,/m/068hy,/m/07qrkrw,/m/07r81j2,/m/0jbk
# 370      /m/01yrx,/m/068hy,/m/07qrkrw,/m/07r81j2,/m/0jbk
# ...                                                  ...
# 19701                /m/01yrx,/m/02yds9,/m/068hy,/m/0jbk
# 20151               /m/01yrx,/m/03qc9zr,/m/068hy,/m/0jbk
# 20164                /m/01yrx,/m/02yds9,/m/068hy,/m/0jbk
# 20298                /m/01yrx,/m/02yds9,/m/068hy,/m/0jbk
# 20365                          /m/01yrx,/m/0cdnk,/m/0jbk
#
#                                              Label_names  \
# 79     Cat,Domestic animals, pets,Meow,Yip,Bow-wow,Sp...
# 224    Cat,Domestic animals, pets,Meow,Caterwaul,Spee...
# 269     Cat,Domestic animals, pets,Meow,Caterwaul,Animal
# 366     Cat,Domestic animals, pets,Meow,Caterwaul,Animal
# 370     Cat,Domestic animals, pets,Meow,Caterwaul,Animal
# ...                                                  ...
# 19701             Cat,Purr,Domestic animals, pets,Animal
# 20151        Cat,Screaming,Domestic animals, pets,Animal
# 20164             Cat,Purr,Domestic animals, pets,Animal
# 20298             Cat,Purr,Domestic animals, pets,Animal
# 20365            Cat,Roaring cats (lions, tigers),Animal
#
#                                                    title
# 79     ERROR: This video has been removed for violati...
# 224                СУПЕР !!! Кот УРИ отвечает... CAT URI
# 269                                             Cute Cat
# 366              Maine Coon Cat Is Anxious For Breakfast
# 370                                            Cat Speak
# ...                                                  ...
# 19701                  Kitten, about 1 week old, purring
# 20151                           Bo reacts to cat screams
# 20164                                   Cat purr - Loud.
# 20298  Adorable rescue kittens purring SO loud!  (bes...
# 20365                           ERROR: Video unavailable
#
# [109 rows x 7 columns]
